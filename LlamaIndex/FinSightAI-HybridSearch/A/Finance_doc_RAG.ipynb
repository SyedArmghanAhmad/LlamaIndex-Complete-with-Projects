# %%
from llama_index.core import VectorStoreIndex, Document
from llama_index.retrievers.bm25 import BM25Retriever
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.llms.groq import Groq
from llama_index.core.node_parser import SentenceSplitter  # For chunking
from PyPDF2 import PdfReader
from pathlib import Path
import os
from dotenv import load_dotenv
import time  # For rate limiting

# Load environment variables
load_dotenv()
# Out:
# True

# %%
# 1. Process PDFs with chunking
def get_pdf_docs(pdf_folder="financial_pdfs", chunk_size=512):
    docs = []
    splitter = SentenceSplitter(chunk_size=chunk_size)
    
    for pdf_file in Path(pdf_folder).glob("*.pdf"):
        reader = PdfReader(pdf_file)
        full_text = "\n".join([page.extract_text() for page in reader.pages])
        
        # Create a base document
        base_doc = Document(text=full_text, metadata={"source": pdf_file.name, "type": "10-K"})
        
        # Split text into manageable chunks
        nodes = splitter.get_nodes_from_documents([base_doc])
        for node in nodes:
            # Convert nodes back to Document objects
            docs.append(Document(
                text=node.text,
                metadata=node.metadata
            ))
    
    return docs

# %%
# 2. Initialize Groq with rate limiting
def initialize_groq():
    groq_api_key = os.getenv("GROQ_API_KEY")
    if not groq_api_key:
        raise ValueError("GROQ_API_KEY not found in .env file")
    return Groq(model="mixtral-8x7b-32768", api_key=groq_api_key)  # Larger context model

# %%
def generate_answer(llm, query, contexts):
    combined_context = "\n".join(contexts)[:4000]  # Increased context size
    prompt = f"""You are a financial analyst. Answer the following question based on the provided context.
    
    Question: {query}
    
    Relevant Context: {combined_context}
    
    Instructions:
    - If the question involves comparisons, rankings, or multiple data points, format the answer as a complete table with all requested data.
    - If the question requires step-by-step explanations or lists, use numbered or bullet points.
    - If data is missing, explicitly state "Data not available in the provided context."
    - Do not use placeholders like X, Y, or Z. If data is missing, leave the cell blank and add a note.
    - Keep the answer concise, accurate, and well-formatted.
    
    Answer:"""
    
    try:
        response = llm.complete(
            prompt=prompt,
            max_tokens=500,
            temperature=0.3
        )
        return response.text.strip()
    except Exception as e:
        return f"Error generating answer: {str(e)}"

# %%
# 4. Interactive hybrid search
def main():
    # Load documents with chunking
    financial_docs = get_pdf_docs()
    
    # Setup retrievers
    embed_model = HuggingFaceEmbedding("BAAI/bge-small-en-v1.5")
    vector_index = VectorStoreIndex.from_documents(financial_docs, embed_model=embed_model)
    
    vector_retriever = vector_index.as_retriever(similarity_top_k=3)
    bm25_retriever = BM25Retriever.from_defaults(nodes=financial_docs, similarity_top_k=3)
    
    # Initialize Groq
    llm = initialize_groq()
    
    # Interactive loop
    while True:
        query = input("\nEnter your financial question (type 'exit' to quit): ")
        if query.lower() in ['exit', 'quit']:
            break
        
        # Retrieve results
        vector_results = vector_retriever.retrieve(query)
        bm25_results = bm25_retriever.retrieve(query)
        
        # Combine and deduplicate
        combined_results = {r.node.node_id: r for r in vector_results + bm25_results}
        
        # Prepare context
        contexts = [result.node.text for result in combined_results.values()]
        
        # Generate and display answer
        answer = generate_answer(llm, query, contexts)
        print("\nAI Answer:")
        print(answer)
        time.sleep(1)  # Rate limit protection

if __name__ == "__main__":
    main()
# Out:
# AI Answer:
# The key findings about household income in 2023 are as follows:
#
# 1. A sizeable share of adults reported that their family's monthly income increased in 2023 compared to the previous year. However, an even greater share of adults indicated that their spending increased from the prior year.
# 2. The proportion of adults who spent less than their income in the month before the survey remained lower than the level it had been before the pandemic, suggesting that fewer adults have margin in their family budgets.
# 3. Nineteen percent of adults had a family income below $25,000, and 37 percent had a family income of $100,000 or more.
# 4. Although labor earnings were the most common source of income, many people had other sources of income. Two-thirds of adults received labor income, and 55 percent of all adults received non-labor income in 2023.
#
# Here is a table summarizing the financial well-being of households by income brackets in 2023:
#
# | Income Bracket   | Financial Well-being (doing at least okay) |
# |-----------------|------------------------------------------|
# | < $25,000       | 41%                                       |
# | $25,000 - $49,999| 51%                                       |
# | $50,000 - $99,999| 50%                                       |
# | $100,000+      | 63%                                       |
#
# Note: The financial well-being data is based on adults' perceptions of their own finances, local economy, and national economy in 2023.
#
# AI Answer:
# | Financial Performance Indicator | Berkshire Hathaway - 2022 | Berkshire Hathaway - 2023 |
# |---------------------------------|---------------------------|---------------------------|
# | Net earnings (loss)            | ($23 billion)             | $96 billion               |
# | Data source                    | Page K-72                 | Page K-72                 |
#
# AI Answer:
# Based on the provided context, the top 5 risks mentioned in the Berkshire Hathaway report, ranked by severity, are:
#
# 1. Mistakes in assessing insurance risks: This is the most severe risk as it can take many years to surface and ripen, with potential losses being huge. (Reference: "Mistakes in assessing insurance risks can be huge and can take many years – even decades – to surface and ripen.")
#
# 2. Major catastrophe: A significant event such as a hurricane, earthquake, or a total surprise like a cyber attack can cause massive losses. (Reference: "A major catastrophe that will dwarf hurricanes Katrina and Ian will occur – perhaps tomorrow, perhaps many decades from now.")
#
# 3. Cybersecurity risks: Although not explicitly ranked, the report mentions cybersecurity as a significant risk factor. (Reference: "Cybersecurity... K-28")
#
# 4. Legal proceedings: The report also highlights legal proceedings as a potential risk. (Reference: "Legal Proceedings... K-32")
#
# 5. Internal control risks: The report includes a section on management's discussion of internal controls, indicating its importance and potential risk. (Reference: "Management’s Report on Internal Controls... K-66")
#
# Please note that the severity of these risks is inferred from the context and not explicitly ranked in the report.
#
# AI Answer:
# I'm unable to provide the exact table as the specific investment values are not provided in the context. However, I can show you how the table would look like with the available information.
#
# | Year | Investment Name            | Value                                                 |
# |------|---------------------------|---------------------------------------------------------|
# | 2022 | Not available in context  | Data not available in the provided context               |
# | 2023 | Not available in context  | Data not available in the provided context               |
#
# Please provide the specific investment names or additional context for me to give you a more detailed answer.
#
# AI Answer:
# | Metric | 2022 | 2023 |
# |---|---|---|
# | Savings Rate (share of adults who spent less than their income in the month before the survey) | 83.3% | 86.7% |
# | Ability to Pay Unexpected Expenses (share who would pay for an unexpected $400 expense with cash or equivalent) | 53.3% | 59.0% |
# | Retirement Savings on Track (share among non-retired adults) | Data not available in the provided context |
# | Job Starts Rate | Data not available in the provided context |
# | Pay Raise Rate | Data not available in the provided context |
# | Prime-age Adults Not Working Due to Difficulty Finding Work | Data not available in the provided context |
# | Financial Stress (share of lower-income adults experiencing material hardships) | Data not available in the provided context |
# | Parents' Financial Well-being (compared to other adults) | Data not available in the provided context |
#
# Notes:
# - Data for the 2023 Savings Rate and Ability to Pay Unexpected Expenses is inferred from the text, while other data points are not explicitly mentioned in the provided context.
# - Retirement Savings on Track data for 2022 is missing.
# - Job Starts Rate, Pay Raise Rate, and Prime-age Adults Not Working Due to Difficulty Finding Work data for both 2022 and 2023 is missing.
# - Financial Stress data for both 2022 and 2023 is missing.
# - Parents' Financial Well-being data for 2022 is missing.
#
# AI Answer:
# To generate the table showing the percentage of households in different income brackets, we will use the "Family income" data from Table 27. Since the question doesn't specify whether to include homeowners or renters, I will calculate the percentages based on all households.
#
# | Income Bracket | Percentage |
# | --- | --- |
# | Less than $25,000 | 26 |
# | $25,000 - $49,999 | 45 |
# | $50,000 - $99,999 | 6 |
# | $100,000 or more | 57 |
#
# Note: These percentages are based on all adults in the survey. The "Family income" category includes income from all sources, such as labor income, non-labor income, Social Security, pension, SSI, TANF, or cash assistance from welfare programs, and unemployment income (Table 3 and Table 13).
#
# AI Answer:
# Here is the table comparing the underwriting profits of Berkshire Hathaway's insurance subsidiaries in 2022 and 2023:
#
# | Category | 2022 ($ millions) | 2023 ($ millions) |
# |---|---|---|
# | Insurance-underwriting | ($30) | 5,428 |
# | Data not available in the provided context | Data not available in the provided context | Data not available in the provided context |
#
# Although the text provides the underwriting profits for 2022 and 2023, it does not offer a breakdown of the underwriting profits by subsidiary. Therefore, I cannot create a more detailed table.
#
# AI Answer:
# Based on the provided context, the key factors contributing to the increase in household income in 2023 are:
#
# 1. Improvement in the national economy: The percentage of adults who rated the national economy as good or excellent increased from 2022 to 2023.
# 2. Increase in non-labor income: A higher share of adults received non-labor income in 2023 compared to 2022.
# 3. Rise in labor income: Two-thirds of adults and their spouse or partner received wages, salaries, or self-employment income in 2023.
#
# Here is the data from the context to support these factors:
#
# | Year | National economy (good or excellent) | Local economy (good or excellent) | Own finances (doing at least okay) |
# |---|---|---|---|
# | 2023 | 75% | 57% | 50% |
# | 2022 | 74% | 51% | 50% |
#
# Table 3 (not fully provided in the context) shows that labor income is the most common source of income, and the share of adults who received interest, dividends, or rental income was higher in 2023 than in 2022.
#
# Figure 8 indicates that 37% of adults had a family income of $100,000 or more in 2023.
#
# Figure 9 shows that 34% of adults said their family's monthly income increased in 2023 compared to the prior year.
#
# AI Answer:
# Based on the provided context, the top 5 challenges faced by U.S. households in 2023, ranked by prevalence, are:
#
# 1. Inflation (35%)
# 2. Basic living expenses (e.g., utilities, transportation, etc.) (13%)
# 3. Housing (e.g., rent, mortgage, etc.) (12%)
# 4. Education debt (9%)
# 5. Medical expenses (9%)
#
# Note: Data on the prevalence of employment and retirement concerns in 2023 is not available in the provided context.
#
# AI Answer:
# 1. Issued an aggregate ¥286.4 billion (approximately $2.0 billion) of senior notes.
# 2. Repaid approximately $4.3 billion of maturing senior notes.
# 3. Experienced a decrease of $371 million in the carrying value of Berkshire parent company debt from changes in foreign currency exchange rates on its non-U.S. Dollar-denominated debt.
#
# Note: The table format is not applicable for this question as it requires a list of steps in chronological order.
#
# AI Answer:
# Based on the 2023 Household Income Report, here are the top 5 recommendations for improving financial well-being:
#
# 1. **Increase income stability**: The report indicates that income variability is a significant challenge for many households. To improve financial well-being, consider strategies that increase income stability, such as diversifying income sources, negotiating for more predictable pay, or seeking employment with steadier hours.
#
# 2. **Reduce expenses**: Households should evaluate their regular expenses and look for ways to reduce costs. This could include shopping around for better deals on insurance, utilities, and other bills, as well as finding more cost-effective options for food and transportation.
#
# 3. **Build emergency savings**: The report highlights the importance of having emergency savings to cover unexpected expenses. Households should aim to save at least three to six months' worth of living expenses to provide a financial safety net.
#
# 4. **Improve credit outcomes**: The report shows that credit outcomes and perceptions can impact financial well-being. Households should focus on improving their credit scores by paying bills on time, reducing debt, and checking their credit reports for errors.
#
# 5. **Invest in retirement**: The report emphasizes the need for households to plan for retirement. This could include contributing to a 401(k) or IRA, seeking professional financial advice, and creating a comprehensive retirement plan.
#
# Data not available in the provided context:
# - Specific income levels or ranges for recommendations
# - Detailed data on the effectiveness of these recommendations for different demographic groups
#
# AI Answer:
# The key findings about household income in 2023 are as follows:
#
# 1. A sizeable share of adults reported that their family's monthly income increased in 2023 compared to the previous year.
# 2. However, an even greater share of adults indicated that their spending increased from the prior year.
# 3. The share of adults who said they spent less than their income in the month before the survey remained low, suggesting that fewer adults have margin in their family budgets.
# 4. Nineteen percent of adults had a family income below $25,000, and 37 percent had a family income of $100,000 or more.
# 5. Although labor earnings were the most common source of income, many people had other sources of income. Two-thirds of adults received labor income, and 55 percent of all adults received non-labor income in 2023.
#
# Here is a table summarizing the income brackets and their financial well-being:
#
# | Income Bracket | Percentage of Adults | Financial Well-being |
# | --- | --- | --- |
# | < $25,000 | 19% | Not specified |
# | $25,000 - $49,999 | Not specified | Not specified |
# | $50,000 - $74,999 | 24% | Not specified |
# | $75,000 - $99,999 | Not specified | Not specified |
# | $100,000 or more | 37% | Not specified |
#
# Note: Financial well-being data is not available for each income bracket in the provided context.
#
# AI Answer:
# Here is the summary of Berkshire Hathaway's financial performance in 2023, including a table comparing revenue, net income, and total assets to 2022:
#
# Financial Performance Summary:
# - Revenue: Data not available in the provided context.
# - Net Income:
#   - 2021: $90 billion
#   - 2022: ($23 billion)
#   - 2023: $96 billion
# - Operating Earnings:
#   - 2021: $27.6 billion
#   - 2022: $30.9 billion
#   - 2023: $37.4 billion
# - Total Assets:
#   - 2022: $857 billion
#   - 2023: $923 billion
#
# Table:
#
# | Financial Metric | 2022 | 2023 |
# |------------------|-------|-------|
# | Net Income       | ($23B)| $96B  |
# | Operating Earnings| $30.9B| $37.4B|
# | Total Assets     | $857B | $923B |
#
# Note: Revenue data was not available in the provided context.
#
# AI Answer:
# The top 5 risks mentioned in the Berkshire Hathaway report are:
#
# 1. Mistakes in assessing insurance risks: Berkshire Hathaway acknowledges the potential for significant losses due to errors in evaluating insurance risks, which may not become apparent for many years.
#
# 2. Major catastrophes: The report highlights the inevitability of a major catastrophe, such as a hurricane or earthquake, that will result in substantial losses for the company.
#
# 3. Unforeseen disasters: Berkshire Hathaway also mentions the risk of unanticipated disasters, such as a cyber attack, causing widespread damage and leading to significant claims.
#
# 4. Market fluctuations: As a financial holding company, Berkshire Hathaway is exposed to market risks, including fluctuations in the value of its investments and derivatives.
#
# 5. Regulatory and legal risks: The company faces potential risks from regulatory changes and legal proceedings, which could negatively impact its financial performance.
#
# Below is a table summarizing the potential impact of these risks:
#
# | Risk                              | Potential Impact                                                                                       |
# |----------------------------------|-----------------------------------------------------------------------------------------------------------|
# | Insurance risk assessment errors  | Significant losses over many years; potential for reputational damage                                       |
# | Major catastrophes                | Large, immediate financial losses; possible strain on resources                                            |
# | Unforeseen disasters             | Unpredictable financial impact; potential for widespread consequences                                       |
# | Market fluctuations                | Variable impact on investment values; potential for reduced earnings                                      |
# | Regulatory and legal risks          | Financial penalties; potential for reputational damage; impact on operations                              |
#
# Please note that the table provided is a simplified representation of the risks and potential impacts mentioned in the report. The actual impact of these risks may vary depending on the specific circumstances.
#
# AI Answer:
# Based on the provided context, here are the trends in U.S. household spending in 2023:
#
# | Spending Category | Percentage Change from 2022 |
# |------------------|-----------------------------|
# | Housing           | Similar to 2022            |
# | Food/Groceries    | Increased (specifically mentioned by those with income under $100,000) |
# | Medical           | Similar to 2022            |
# | Retirement        | Decreased (consistent with the increase in the share of people who thought their retirement savings were on track) |
# | Employment        | Similar to 2022            |
# | Education Debt    | Not explicitly mentioned in the text |
# | Inflation         | Similar to 2022            |
# | Basic Living Expenses | Similar to 2022 |
# | Economic Well-being (overall) | Not explicitly mentioned in the text |
#
# Note:
# - Data for some spending categories, such as transportation and entertainment, is not available in the provided context.
# - The percentage changes are inferred from the text and not directly provided in the data.
# - The categories are not mutually exclusive, meaning that households might have experienced changes in multiple categories.
#
# AI Answer:
# The investment strategy of Berkshire Hathaway in 2023, as outlined by Warren Buffett in the annual report, focuses on acquiring large companies with strong fundamentals and attractive valuations, both in the U.S. and internationally. However, due to Berkshire's massive size and increased competition, finding suitable investments has become increasingly difficult.
#
# Here are the top 5 investments of Berkshire Hathaway in 2023 along with their performance:
#
# | Rank | Company Name           | Industry           | Cost Basis (2023) | Market Value (2023) | Performance   |
# |------|-----------------------|--------------------|------------------|-------------------|---------------|
# | 1    | Apple Inc.            | Technology         | $39,099,000,000  | $52,951,000,000   | 35.4%         |
# | 2    | Bank of America Corp. | Finance            | $24,333,000,000  | $33,441,000,000   | 37.7%         |
# | 3    | American Express Co.   | Finance            | $15,335,000,000  | $20,512,000,000   | 33.7%         |
# | 4    | The Coca-Cola Company  | Consumer Goods    | $17,874,000,000  | $22,923,000,000   | 28.2%         |
# | 5    | Verizon Communications  | Telecommunications  | $8,550,000,000    | $11,354,000,000   | 32.8%         |
#
# *Data not available in the provided context: Performance is calculated as (Market Value / Cost Basis - 1) * 100% for each investment.
