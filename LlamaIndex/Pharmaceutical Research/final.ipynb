# %%
from llama_index.core import VectorStoreIndex, Document,Settings
from llama_index.llms.groq import Groq
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core.vector_stores import MetadataFilter, MetadataFilters
import pandas as pd
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
# Initialize models BEFORE anything else
groq_api_key = os.getenv("GROQ_API_KEY")
Settings.llm = Groq(model="mixtral-8x7b-32768", api_key=groq_api_key)
Settings.embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
### Expanded Clinical Trial Dataset
expanded_data = {
    "NCTId": [
        "NCT04512345", "NCT05678901", "NCT03456789", "NCT07890123",
        "NCT09876543", "NCT11223344", "NCT22334455", "NCT33445566",
        "NCT44556677", "NCT55667788"
    ],
    "Title": [
        "Study of Drug X in Alzheimer's Patients",
        "Trial of Compound Y for Early Alzheimer's",
        "Investigation of Drug Z for Parkinson's",
        "Study of Therapy A for Multiple Sclerosis",
        "Study of Drug B for Alzheimer's",
        "Long-term Cognitive Outcomes in Alzheimer's",
        "Gene Therapy Trial for Parkinson's Disease",
        "Stem Cell Treatment for Multiple Sclerosis",
        "Preventive Vaccine for Alzheimer's",
        "Digital Therapy for Parkinson's Symptom Management"
    ],
    "Condition": [
        "Alzheimer's Disease", "Alzheimer's Disease",
        "Parkinson's Disease", "Multiple Sclerosis",
        "Alzheimer's Disease", "Alzheimer's Disease",
        "Parkinson's Disease", "Multiple Sclerosis",
        "Alzheimer's Disease", "Parkinson's Disease"
    ],
    "Phase": [
        "Phase 2", "Phase 3", "Phase 1", "Phase 2",
        "Phase 2", "Phase 4", "Phase 1/2", "Phase 3",
        "Phase 2", "Phase 3"
    ],
    "Status": [
        "Recruiting", "Completed", "Active", "Recruiting",
        "Recruiting", "Completed", "Not yet recruiting", "Active",
        "Terminated", "Recruiting"
    ],
    "StartDate": [
        "2023-01-01", "2022-06-15", "2023-03-01", "2023-05-01",
        "2023-07-01", "2021-09-01", "2024-01-01", "2023-10-01",
        "2023-04-01", "2023-12-01"
    ],
    "CompletionDate": [
        "2024-12-31", "2023-12-31", "2024-06-30", "2025-01-31",
        "2024-12-31", "2023-06-30", "2026-12-31", "2025-06-30",
        "2023-12-31", "2025-06-30"
    ],
    "Interventions": [
        ["Drug X", "Placebo"],
        ["Compound Y", "Cognitive Therapy"],
        ["Drug Z"],
        ["Therapy A", "Placebo"],
        ["Drug B", "Placebo"],
        ["Cognitive Assessment", "MRI Scans"],
        ["Gene Therapy Vector"],
        ["Stem Cell Injection"],
        ["Vaccine X-101"],
        ["Digital Therapy App"]
    ],
    "Description": [
        "A study to evaluate the efficacy of Drug X in Alzheimer's patients.",
        "A trial to assess the safety and efficacy of Compound Y in early Alzheimer's.",
        "An investigation into the pharmacokinetics of Drug Z in Parkinson's patients.",
        "A study to evaluate the effectiveness of Therapy A in Multiple Sclerosis patients.",
        "A study to evaluate the efficacy of Drug B in Alzheimer's patients.",
        "Long-term follow-up study of cognitive outcomes in Alzheimer's patients.",
        "First-in-human trial of gene therapy for Parkinson's disease.",
        "Phase 3 trial of stem cell therapy for progressive Multiple Sclerosis.",
        "Phase 2 trial of preventive vaccine for high-risk Alzheimer's patients (terminated due to safety concerns).",
        "Digital therapy app for managing Parkinson's motor symptoms."
    ]
}

trials_df = pd.DataFrame(expanded_data)

# %%
trials_df
# Out:
#          NCTId                                              Title  \
# 0  NCT04512345            Study of Drug X in Alzheimer's Patients
# 1  NCT05678901          Trial of Compound Y for Early Alzheimer's
# 2  NCT03456789            Investigation of Drug Z for Parkinson's
# 3  NCT07890123          Study of Therapy A for Multiple Sclerosis
# 4  NCT09876543                    Study of Drug B for Alzheimer's
# 5  NCT11223344        Long-term Cognitive Outcomes in Alzheimer's
# 6  NCT22334455         Gene Therapy Trial for Parkinson's Disease
# 7  NCT33445566         Stem Cell Treatment for Multiple Sclerosis
# 8  NCT44556677                 Preventive Vaccine for Alzheimer's
# 9  NCT55667788  Digital Therapy for Parkinson's Symptom Manage...
#
#              Condition      Phase              Status   StartDate  \
# 0  Alzheimer's Disease    Phase 2          Recruiting  2023-01-01
# 1  Alzheimer's Disease    Phase 3           Completed  2022-06-15
# 2  Parkinson's Disease    Phase 1              Active  2023-03-01
# 3   Multiple Sclerosis    Phase 2          Recruiting  2023-05-01
# 4  Alzheimer's Disease    Phase 2          Recruiting  2023-07-01
# 5  Alzheimer's Disease    Phase 4           Completed  2021-09-01
# 6  Parkinson's Disease  Phase 1/2  Not yet recruiting  2024-01-01
# 7   Multiple Sclerosis    Phase 3              Active  2023-10-01
# 8  Alzheimer's Disease    Phase 2          Terminated  2023-04-01
# 9  Parkinson's Disease    Phase 3          Recruiting  2023-12-01
#
#   CompletionDate                      Interventions  \
# 0     2024-12-31                  [Drug X, Placebo]
# 1     2023-12-31    [Compound Y, Cognitive Therapy]
# 2     2024-06-30                           [Drug Z]
# 3     2025-01-31               [Therapy A, Placebo]
# 4     2024-12-31                  [Drug B, Placebo]
# 5     2023-06-30  [Cognitive Assessment, MRI Scans]
# 6     2026-12-31              [Gene Therapy Vector]
# 7     2025-06-30              [Stem Cell Injection]
# 8     2023-12-31                    [Vaccine X-101]
# 9     2025-06-30              [Digital Therapy App]
#
#                                          Description
# 0  A study to evaluate the efficacy of Drug X in ...
# 1  A trial to assess the safety and efficacy of C...
# 2  An investigation into the pharmacokinetics of ...
# 3  A study to evaluate the effectiveness of Thera...
# 4  A study to evaluate the efficacy of Drug B in ...
# 5  Long-term follow-up study of cognitive outcome...
# 6  First-in-human trial of gene therapy for Parki...
# 7  Phase 3 trial of stem cell therapy for progres...
# 8  Phase 2 trial of preventive vaccine for high-r...
# 9  Digital therapy app for managing Parkinson's m...

# %%
### Document Conversion
# %%
def trials_to_documents(trials_df):
    """Convert DataFrame to LlamaIndex Documents with complete metadata"""
    documents = []
    for _, row in trials_df.iterrows():
        metadata = {
            "NCTId": row["NCTId"],
            "Title": row["Title"],
            "Condition": row["Condition"],
            "Phase": row["Phase"],
            "Status": row["Status"],
            "Interventions": ", ".join(row["Interventions"]),
            "StartDate": row["StartDate"],
            "CompletionDate": row["CompletionDate"],
            "Description": row["Description"]
        }
        text = f"{row['Description']}"  # Simplified text content
        documents.append(Document(text=text, metadata=metadata))
    return documents

def _explain_phase(phase):
    return {
        "Phase 1": "Initial safety testing in small groups (20-80 participants)",
        "Phase 2": "Efficacy and side effect testing in larger groups (100-300)",
        "Phase 3": "Large-scale testing for regulatory approval (1,000-3,000)",
        "Phase 4": "Post-marketing surveillance after approval",
        "Phase 1/2": "Combined safety and preliminary efficacy testing"
    }.get(phase, "Clinical trial stage")

def _explain_status(status):
    return {
        "Recruiting": "Currently accepting participants",
        "Completed": "Finished data collection, results analysis ongoing",
        "Active": "Ongoing but not currently recruiting",
        "Terminated": "Permanently stopped before completion",
        "Not yet recruiting": "Approved but not yet started"
    }.get(status, "Trial status")

# %%
### Query Engine
# %%
def get_query_engine(index, filters=None):
    """Create configured query engine"""
    return index.as_query_engine(
        similarity_top_k=5,
        filters=filters,
        verbose=False
    )

# %%
# %% [markdown]
### Enhanced Response Formatting
# %%
def format_response(response, question):
    """Generate human-friendly explanations with context"""
    if not response or not response.source_nodes:
        return "No matching trials found based on your criteria."
    
    # Generate natural language summary
    base_prompt = f"""Context: {response}
    Task: Explain these clinical trial results to a healthcare worker.
    Requirements:
    1. Answer the question: {question}
    2. Highlight key trial aspects
    3. Explain technical terms in parentheses
    4. Use bullet points
    5. Keep under 300 words"""
    
    summary = Settings.llm.complete(base_prompt).text
    
    # Build detailed metadata section
    details = []
    for node in response.source_nodes[:3]:  # Show top 3 most relevant
        meta = node.metadata
        details.append(f"""
        Trial ID: {meta['NCTId']}
        • Title: {meta['Title']}
        • Condition: {meta['Condition']}
        • Phase: {meta['Phase']} ({_explain_phase(meta['Phase'])})
        • Status: {meta['Status']} ({_explain_status(meta['Status'])})
        • Interventions: {meta['Interventions']}
        • Timeline: {meta['StartDate']} to {meta['CompletionDate']}
        """)
    
    return f"""
    {summary.strip()}
    
    Detailed Information:
    {"".join(details)}
    """
    
def query_trials(index, question, phase=None, status=None):
    """Query the index with optional metadata filters"""
    filters = []
    if phase:
        filters.append(MetadataFilter(key="Phase", value=phase))
    if status:
        filters.append(MetadataFilter(key="Status", value=status))
    
    # Correct initialization
    metadata_filters = MetadataFilters(filters=filters) if filters else None
    
    query_engine = index.as_query_engine(
        similarity_top_k=5,
        filters=metadata_filters
    )
    return query_engine.query(question)

# %%
### Interactive System
def interactive_query_system():
    print("\n🚀 Clinical Trial Intelligence System")
    print("➤ Type 'exit' to quit")
    print("➤ Available filters: Phase, Status\n")
    
    # Initialize with complete dataset
    documents = trials_to_documents(pd.DataFrame(expanded_data))
    index = VectorStoreIndex.from_documents(
        documents,
        embed_model=Settings.embed_model,
        show_progress=True
    )
    
    while True:
        try:
            # Get user input
            question = input("\n❔ Your question: ").strip()
            if question.lower() in ['exit', 'quit']:
                print("\n👋 Ending session...")
                break
                
            # Get filters
            phase = input("⚙️  Filter by Phase (optional): ").strip()
            status = input("⚙️  Filter by Status (optional): ").strip()
            
            # Build filters
            filters = []
            if phase:
                filters.append(MetadataFilter(key="Phase", value=phase))
            if status:
                filters.append(MetadataFilter(key="Status", value=status))
            
            # Execute query
            query_engine = index.as_query_engine(
                similarity_top_k=5,
                filters=MetadataFilters(filters=filters) if filters else None
            )
            raw_response = query_engine.query(question)
            
            # Format response
            formatted_response = format_response(raw_response, question)
            
            # Display results
            print("\n" + "="*80)
            print(formatted_response.strip())
            print("="*80)
            
        except Exception as e:
            print(f"\n❌ Error: {str(e)}\n")
if __name__ == "__main__":
    interactive_query_system()
# Out:
# 🚀 Clinical Trial Intelligence System
# ➤ Type 'exit' to quit
# ➤ Available filters: Phase, Status
# Parsing nodes: 100%|██████████| 10/10 [00:00<00:00, 3901.68it/s]
# Generating embeddings: 100%|██████████| 10/10 [00:00<00:00, 18.84it/s]
# ================================================================================
# What are the latest Alzheimer's trials?
#
# The two most recent Alzheimer's trials are:
#
# 1. NCT09876543, "Study of Drug B for Alzheimer's"
# 2. NCT04512345, "Study of Drug X in Alzheimer's Patients"
#
# Highlighted trial aspects:
#
# - Both trials are in Phase 2, which means they are testing the drug's effectiveness and monitoring side effects.
# - They are currently recruiting participants.
# - The primary objective of both trials is to evaluate the efficacy of the drugs in Alzheimer's patients.
#
# Explanation of technical terms:
#
# - (Phase 2): This is the second stage of clinical trials, where researchers test the drug's safety and effectiveness in a larger group of people.
# - (Recruiting): This means the trial is actively seeking participants to enroll.
# - (Efficacy): This refers to the ability of a drug to produce the desired effect.
#
# Additional trial details:
#
# NCT09876543, "Study of Drug B for Alzheimer's":
#
# - Start date: July 2023
# - Drug B's trial aims to assess the efficacy of Drug B in Alzheimer's patients.
#
# NCT04512345, "Study of Drug X in Alzheimer's Patients":
#
# - Start date: January 2023
# - Drug X's trial also aims to evaluate the efficacy of Drug X in Alzheimer's patients.
#
# In summary, the two latest Alzheimer's trials are NCT09876543 and NCT04512345, both in Phase 2 and currently recruiting participants. These trials are focused on evaluating the efficacy of Drug B and Drug X in Alzheimer's patients, with Drug B's trial starting in July 2023 and Drug X's trial starting in January 2023.
#
#     Detailed Information:
#
#         Trial ID: NCT09876543
#         • Title: Study of Drug B for Alzheimer's
#         • Condition: Alzheimer's Disease
#         • Phase: Phase 2 (Efficacy and side effect testing in larger groups (100-300))
#         • Status: Recruiting (Currently accepting participants)
#         • Interventions: Drug B, Placebo
#         • Timeline: 2023-07-01 to 2024-12-31
#
#         Trial ID: NCT04512345
#         • Title: Study of Drug X in Alzheimer's Patients
#         • Condition: Alzheimer's Disease
#         • Phase: Phase 2 (Efficacy and side effect testing in larger groups (100-300))
#         • Status: Recruiting (Currently accepting participants)
#         • Interventions: Drug X, Placebo
#         • Timeline: 2023-01-01 to 2024-12-31
#
#         Trial ID: NCT05678901
#         • Title: Trial of Compound Y for Early Alzheimer's
#         • Condition: Alzheimer's Disease
#         • Phase: Phase 3 (Large-scale testing for regulatory approval (1,000-3,000))
#         • Status: Completed (Finished data collection, results analysis ongoing)
#         • Interventions: Compound Y, Cognitive Therapy
#         • Timeline: 2022-06-15 to 2023-12-31
# ================================================================================
#
# ================================================================================
# No matching trials found based on your criteria.
# ================================================================================
#
# ================================================================================
# Sure, here are some clinical trials related to Parkinson's disease:
#
# * NCT22334455: This is a Phase 1/2 trial studying the first-in-human use of gene therapy for Parkinson's disease. The trial is not yet recruiting and is set to start on January 1, 2024.
# 	+ Gene therapy involves the use of genes to treat or prevent disease.
# 	+ In this trial, the gene therapy will be used to modify or replace genes that are involved in Parkinson's disease.
# * NCT55667788: This is a Phase 3 trial investigating the use of a digital therapy app to manage Parkinson's motor symptoms. The trial is currently recruiting and is set to start on December 1, 2023.
# 	+ Digital therapy refers to the use of technology, such as apps or wearable devices, to deliver therapeutic interventions.
# 	+ In this trial, the digital therapy app will be used to help manage motor symptoms, such as tremors or stiffness, in Parkinson's patients.
# * NCT03456789: This is a Phase 1 trial studying the pharmacokinetics of Drug Z in Parkinson's patients. The trial is active and started on March 1, 2023.
# 	+ Pharmacokinetics refers to the way a drug is absorbed, distributed, metabolized, and excreted in the body.
# 	+ In this trial, the pharmacokinetics of Drug Z will be studied in Parkinson's patients to determine its safety and effectiveness.
#
# I hope this information is helpful! Let me know if you have any other questions.
#
#     Detailed Information:
#
#         Trial ID: NCT22334455
#         • Title: Gene Therapy Trial for Parkinson's Disease
#         • Condition: Parkinson's Disease
#         • Phase: Phase 1/2 (Combined safety and preliminary efficacy testing)
#         • Status: Not yet recruiting (Approved but not yet started)
#         • Interventions: Gene Therapy Vector
#         • Timeline: 2024-01-01 to 2026-12-31
#
#         Trial ID: NCT55667788
#         • Title: Digital Therapy for Parkinson's Symptom Management
#         • Condition: Parkinson's Disease
#         • Phase: Phase 3 (Large-scale testing for regulatory approval (1,000-3,000))
#         • Status: Recruiting (Currently accepting participants)
#         • Interventions: Digital Therapy App
#         • Timeline: 2023-12-01 to 2025-06-30
#
#         Trial ID: NCT03456789
#         • Title: Investigation of Drug Z for Parkinson's
#         • Condition: Parkinson's Disease
#         • Phase: Phase 1 (Initial safety testing in small groups (20-80 participants))
#         • Status: Active (Ongoing but not currently recruiting)
#         • Interventions: Drug Z
#         • Timeline: 2023-03-01 to 2024-06-30
# ================================================================================
#
# ================================================================================
# Hello healthcare worker,
#
# I'd like to share information on two clinical trials utilizing gene therapy:
#
# 1. **NCT022334455 (Phase 1/2 trial for Parkinson's Disease)**:
#    - This trial investigates the safety and efficacy of gene therapy (the introduction of genetic material into cells to treat or prevent diseases) using AAV2-ND3 (a specific type of virus carrying a specific gene) in patients with Parkinson's Disease.
#    - The primary goal is to assess the therapy's ability to improve motor function and reduce motor complications.
#    - Secondary objectives include evaluating the safety and tolerability of the treatment, as well as its impact on non-motor symptoms and quality of life.
#
# 2. **Unspecified Phase 3 trial**:
#    - Although specific details are not provided, it's clear that this trial also involves gene therapy.
#    - Phase 3 trials focus on evaluating the efficacy of a treatment, so this trial will likely provide valuable insights into the real-world benefits of gene therapy for its targeted condition.
#
# Key trial aspects:
# - Both trials use gene therapy, a promising approach for treating various conditions by introducing genetic material into cells.
# - The first trial focuses on Parkinson's Disease, while the second trial's condition remains unspecified.
# - Both trials aim to assess the safety and efficacy of their respective gene therapies.
#
# Technical terms:
# - Gene therapy: the introduction of genetic material into cells to treat or prevent diseases.
# - AAV2-ND3: a specific type of virus (AAV2) carrying a specific gene (ND3) used in the Phase 1/2 trial.
#
# I hope this information is helpful. Let me know if you have any questions or need further clarification.
#
# Best regards,
# [Your Name]
#
#     Detailed Information:
#
#         Trial ID: NCT22334455
#         • Title: Gene Therapy Trial for Parkinson's Disease
#         • Condition: Parkinson's Disease
#         • Phase: Phase 1/2 (Combined safety and preliminary efficacy testing)
#         • Status: Not yet recruiting (Approved but not yet started)
#         • Interventions: Gene Therapy Vector
#         • Timeline: 2024-01-01 to 2026-12-31
#
#         Trial ID: NCT33445566
#         • Title: Stem Cell Treatment for Multiple Sclerosis
#         • Condition: Multiple Sclerosis
#         • Phase: Phase 3 (Large-scale testing for regulatory approval (1,000-3,000))
#         • Status: Active (Ongoing but not currently recruiting)
#         • Interventions: Stem Cell Injection
#         • Timeline: 2023-10-01 to 2025-06-30
#
#         Trial ID: NCT07890123
#         • Title: Study of Therapy A for Multiple Sclerosis
#         • Condition: Multiple Sclerosis
#         • Phase: Phase 2 (Efficacy and side effect testing in larger groups (100-300))
#         • Status: Recruiting (Currently accepting participants)
#         • Interventions: Therapy A, Placebo
#         • Timeline: 2023-05-01 to 2025-01-31
# ================================================================================
#
# ================================================================================
# Hello healthcare worker,
#
# I have found two clinical trials that are currently recruiting participants:
#
# 1. A study evaluating the effectiveness of Therapy A in Multiple Sclerosis (MS) patients.
# - NCTId: NCT07890123
# - Phase: Not specified
# - Study type: Interventional
# - Sponsor: [Sponsor name]
# - Estimated enrollment: 150 participants
# - Condition: Multiple Sclerosis
# - Intervention: Therapy A
# - Purpose: To assess the effectiveness of Therapy A in MS patients
#
# 2. A trial assessing the efficacy of Drug B in Alzheimer's patients.
# - NCTId: NCT09876543
# - Phase: Not specified
# - Study type: Interventional
# - Sponsor: [Sponsor name]
# - Estimated enrollment: 200 participants
# - Condition: Alzheimer's Disease
# - Intervention: Drug B
# - Purpose: To evaluate the efficacy of Drug B in Alzheimer's patients
#
# Key trial aspects:
#
# - Both trials are interventional studies, meaning they involve the use of a specific therapy or drug.
# - Neither trial has specified its phase, which could be Phase 1 (safety), Phase 2 (efficacy), or Phase 3 (effectiveness and safety).
# - The MS trial aims to enroll 150 participants, while the Alzheimer's trial plans to recruit 200.
# - The primary sponsor for both trials is [Sponsor name].
#
# Technical terms:
#
# - NCTId: National Clinical Trial (NCT) Identifier, a unique number assigned to clinical trials registered on ClinicalTrials.gov.
# - Phase: A stage in the development of a new drug or therapy, usually consisting of Phase 1 (safety), Phase 2 (efficacy), and Phase 3 (effectiveness and safety) trials.
# - Interventional study: A type of clinical trial that involves the use of a specific therapy or drug.
# - Sponsor: An individual, organization, or group that takes responsibility for initiating, managing, and/or financing a clinical trial.
#
# I hope this information is helpful. Let me know if you have any questions or need further clarification.
#
# Best regards,
# [Your name]
#
#     Detailed Information:
#
#         Trial ID: NCT07890123
#         • Title: Study of Therapy A for Multiple Sclerosis
#         • Condition: Multiple Sclerosis
#         • Phase: Phase 2 (Efficacy and side effect testing in larger groups (100-300))
#         • Status: Recruiting (Currently accepting participants)
#         • Interventions: Therapy A, Placebo
#         • Timeline: 2023-05-01 to 2025-01-31
#
#         Trial ID: NCT05678901
#         • Title: Trial of Compound Y for Early Alzheimer's
#         • Condition: Alzheimer's Disease
#         • Phase: Phase 3 (Large-scale testing for regulatory approval (1,000-3,000))
#         • Status: Completed (Finished data collection, results analysis ongoing)
#         • Interventions: Compound Y, Cognitive Therapy
#         • Timeline: 2022-06-15 to 2023-12-31
#
#         Trial ID: NCT09876543
#         • Title: Study of Drug B for Alzheimer's
#         • Condition: Alzheimer's Disease
#         • Phase: Phase 2 (Efficacy and side effect testing in larger groups (100-300))
#         • Status: Recruiting (Currently accepting participants)
#         • Interventions: Drug B, Placebo
#         • Timeline: 2023-07-01 to 2024-12-31
# ================================================================================
#
# ================================================================================
# No matching trials found based on your criteria.
# ================================================================================
#
# ================================================================================
# What trials are in Phase 3?
#
# - Trial of Compound Y for early Alzheimer's Disease
# - Phase 3 trial of stem cell therapy for progressive Multiple Sclerosis
#
# Key trial aspects for Compound Y:
#
# - Aimed at early Alzheimer's Disease (AD), a stage characterized by mild cognitive impairment and daily functioning decline
# - Compound Y is an investigational drug, meaning it's not yet approved for use and still being tested for safety and efficacy
# - Phase 3 trials are the last stage before potential FDA approval; they involve larger patient groups and aim to confirm previous findings
# - Primary endpoints may include changes in cognitive function, daily living abilities, and biomarkers (measurable indicators of disease progression)
#
# Key trial aspects for stem cell therapy:
#
# - Focused on progressive Multiple Sclerosis (MS), a stage marked by worsening neurological function and disability accumulation
# - Stem cell therapy is an experimental treatment that uses stem cells (undifferentiated cells capable of developing into various cell types) to potentially repair damaged tissues
# - Phase 3 trials are crucial for evaluating safety, efficacy, and optimal treatment protocols
# - Primary endpoints may include changes in neurological function, disability progression, and quality of life
#
# In summary, Phase 3 trials for Compound Y and stem cell therapy are underway for early AD and progressive MS, respectively. These trials aim to establish safety and efficacy, providing valuable information for potential FDA approval and future treatment options.
#
#     Detailed Information:
#
#         Trial ID: NCT05678901
#         • Title: Trial of Compound Y for Early Alzheimer's
#         • Condition: Alzheimer's Disease
#         • Phase: Phase 3 (Large-scale testing for regulatory approval (1,000-3,000))
#         • Status: Completed (Finished data collection, results analysis ongoing)
#         • Interventions: Compound Y, Cognitive Therapy
#         • Timeline: 2022-06-15 to 2023-12-31
#
#         Trial ID: NCT33445566
#         • Title: Stem Cell Treatment for Multiple Sclerosis
#         • Condition: Multiple Sclerosis
#         • Phase: Phase 3 (Large-scale testing for regulatory approval (1,000-3,000))
#         • Status: Active (Ongoing but not currently recruiting)
#         • Interventions: Stem Cell Injection
#         • Timeline: 2023-10-01 to 2025-06-30
#
#         Trial ID: NCT04512345
#         • Title: Study of Drug X in Alzheimer's Patients
#         • Condition: Alzheimer's Disease
#         • Phase: Phase 2 (Efficacy and side effect testing in larger groups (100-300))
#         • Status: Recruiting (Currently accepting participants)
#         • Interventions: Drug X, Placebo
#         • Timeline: 2023-01-01 to 2024-12-31
# ================================================================================
#
# ================================================================================
# What Phase 2 trials are recruiting for Alzheimer's?
# - Trial 1: Examining the efficacy of Drug B in Alzheimer's patients
# - Trial 2: Assessing the efficacy of Drug X in Alzheimer's patients
#
# Highlighting key trial aspects:
#
# Trial 1:
# - Objective: Investigate Drug B's impact on cognitive function and daily living abilities in Alzheimer's patients
# - Design: Randomized, double-blind, placebo-controlled trial
# - Participants: Mild to moderate Alzheimer's patients, aged 55-85
# - Duration: 18 months
# - Primary outcome: Change in Alzheimer's Disease Assessment Scale-Cognitive Subscale (ADAS-Cog) score
#
# Trial 2:
# - Objective: Evaluate Drug X's potential in slowing cognitive decline and improving daily functioning in Alzheimer's patients
# - Design: Randomized, double-blind, parallel-group trial
# - Participants: Early-stage Alzheimer's patients, aged 60-85
# - Duration: 24 months
# - Primary outcome: Change in Clinical Dementia Rating-Sum of Boxes (CDR-SB) score
#
# Explanation of technical terms:
# - Randomized: Participants are randomly assigned to either the treatment or control group
# - Double-blind: Neither the participants nor the researchers know which group the participants belong to
# - Placebo-controlled: A group receives a harmless, inactive substance (placebo) instead of the actual treatment
# - Parallel-group: Participants are divided into two groups, one receiving the treatment and the other receiving a placebo or standard care
# - Primary outcome: The main result measured to determine the trial's success
#
# ADAS-Cog: A widely used tool to assess cognitive impairment in Alzheimer's patients
# CDR-SB: A method to stage dementia and measure its progression by evaluating various aspects of cognition, behavior, and daily living activities
#
#     Detailed Information:
#
#         Trial ID: NCT09876543
#         • Title: Study of Drug B for Alzheimer's
#         • Condition: Alzheimer's Disease
#         • Phase: Phase 2 (Efficacy and side effect testing in larger groups (100-300))
#         • Status: Recruiting (Currently accepting participants)
#         • Interventions: Drug B, Placebo
#         • Timeline: 2023-07-01 to 2024-12-31
#
#         Trial ID: NCT04512345
#         • Title: Study of Drug X in Alzheimer's Patients
#         • Condition: Alzheimer's Disease
#         • Phase: Phase 2 (Efficacy and side effect testing in larger groups (100-300))
#         • Status: Recruiting (Currently accepting participants)
#         • Interventions: Drug X, Placebo
#         • Timeline: 2023-01-01 to 2024-12-31
#
#         Trial ID: NCT44556677
#         • Title: Preventive Vaccine for Alzheimer's
#         • Condition: Alzheimer's Disease
#         • Phase: Phase 2 (Efficacy and side effect testing in larger groups (100-300))
#         • Status: Terminated (Permanently stopped before completion)
#         • Interventions: Vaccine X-101
#         • Timeline: 2023-04-01 to 2023-12-31
# ================================================================================
#
# ================================================================================
# 1. Answer the question: Show me completed trials for Multiple Sclerosis.
#
# After reviewing the provided information, there are currently no completed clinical trials for Multiple Sclerosis (MS) according to the given context. The study NCT11223344, titled "Long-term Cognitive Outcomes in Alzheimer's," is focused on Alzheimer's Disease and not MS.
#
# 2. Highlight key trial aspects
#
# - NCT11223344:
#   - Title: "Long-term Cognitive Outcomes in Alzheimer's"
#   - Study Type: Interventional
#   - Status: Completed
#   - Condition: Alzheimer's Disease
#   - Interventions: Exercise; Computerized Cognitive Training; Combination of Exercise and Computerized Cognitive Training
#
# 3. Explain technical terms in parentheses
#
# - Interventional Study: A type of clinical trial in which participants are assigned to receive one or more interventions (or no intervention) so that researchers can evaluate the effects of the interventions on biomedical or health-related outcomes.
# - Condition: The disease, disorder, syndrome, or injury being studied.
# - Interventions: Procedures, devices, drugs, or other treatments used in clinical trials.
#
# 4. Use bullet points
#
# - NCT11223344 is an interventional study focused on Alzheimer's Disease.
# - The study involved three interventions: exercise, computerized cognitive training, and a combination of exercise and computerized cognitive training.
# - The status of the study is completed.
# - However, this study does not meet the requirement of showing completed trials for Multiple Sclerosis.
#
# 5. Keep under 300 words
#
# Total word count: 215
#
#     Detailed Information:
#
#         Trial ID: NCT07890123
#         • Title: Study of Therapy A for Multiple Sclerosis
#         • Condition: Multiple Sclerosis
#         • Phase: Phase 2 (Efficacy and side effect testing in larger groups (100-300))
#         • Status: Recruiting (Currently accepting participants)
#         • Interventions: Therapy A, Placebo
#         • Timeline: 2023-05-01 to 2025-01-31
#
#         Trial ID: NCT33445566
#         • Title: Stem Cell Treatment for Multiple Sclerosis
#         • Condition: Multiple Sclerosis
#         • Phase: Phase 3 (Large-scale testing for regulatory approval (1,000-3,000))
#         • Status: Active (Ongoing but not currently recruiting)
#         • Interventions: Stem Cell Injection
#         • Timeline: 2023-10-01 to 2025-06-30
#
#         Trial ID: NCT09876543
#         • Title: Study of Drug B for Alzheimer's
#         • Condition: Alzheimer's Disease
#         • Phase: Phase 2 (Efficacy and side effect testing in larger groups (100-300))
#         • Status: Recruiting (Currently accepting participants)
#         • Interventions: Drug B, Placebo
#         • Timeline: 2023-07-01 to 2024-12-31
# ================================================================================
#
# ================================================================================
# What trials are using stem cell therapy and are in Phase 3?
#
# - A study investigating the use of stem cell therapy for progressive Multiple Sclerosis (MS)
# - An unspecified trial utilizing stem cell injection
#
# Highlight key trial aspects:
#
# Stem cell therapy for progressive MS (NCT01863884):
#
# - This trial, taking place in the United States, aims to assess the safety and efficacy of autologous hematopoietic stem cell transplantation (HSCT) in patients with secondary progressive MS.
# - Participants receive immunoablation (removal of the immune system) followed by autologous HSCT.
# - Primary outcomes include changes in Expanded Disability Status Scale (EDSS) scores and brain volume loss.
# - Enrollment: 120 participants
# - Estimated completion: December 2023
#
# Unspecified stem cell trial:
#
# - This trial, conducted in China, focuses on the therapeutic potential of stem cells for an unspecified medical condition.
# - Participants receive allogeneic mesenchymal stem cells (MSCs) via intravenous injection.
# - Primary outcomes include safety and efficacy assessments.
# - Enrollment: 100 participants
# - Estimated completion: December 2023
#
# Explanation of technical terms:
#
# - Autologous hematopoietic stem cell transplantation (HSCT): A procedure where a patient's own hematopoietic stem cells (blood-forming cells) are collected, stored, and then reinfused after immunoablation.
# - Immunoablation: The deliberate destruction of a patient's immune system to prepare for HSCT.
# - Allogeneic mesenchymal stem cells (MSCs): Stem cells derived from a donor (not the patient) that can differentiate into various cell types.
# - Intravenous injection: The administration of a substance directly into a vein.
#
#     Detailed Information:
#
#         Trial ID: NCT33445566
#         • Title: Stem Cell Treatment for Multiple Sclerosis
#         • Condition: Multiple Sclerosis
#         • Phase: Phase 3 (Large-scale testing for regulatory approval (1,000-3,000))
#         • Status: Active (Ongoing but not currently recruiting)
#         • Interventions: Stem Cell Injection
#         • Timeline: 2023-10-01 to 2025-06-30
#
#         Trial ID: NCT22334455
#         • Title: Gene Therapy Trial for Parkinson's Disease
#         • Condition: Parkinson's Disease
#         • Phase: Phase 1/2 (Combined safety and preliminary efficacy testing)
#         • Status: Not yet recruiting (Approved but not yet started)
#         • Interventions: Gene Therapy Vector
#         • Timeline: 2024-01-01 to 2026-12-31
#
#         Trial ID: NCT05678901
#         • Title: Trial of Compound Y for Early Alzheimer's
#         • Condition: Alzheimer's Disease
#         • Phase: Phase 3 (Large-scale testing for regulatory approval (1,000-3,000))
#         • Status: Completed (Finished data collection, results analysis ongoing)
#         • Interventions: Compound Y, Cognitive Therapy
#         • Timeline: 2022-06-15 to 2023-12-31
# ================================================================================
#
# ================================================================================
# What are the latest trials for Alzheimer's that are using drug interventions?
#
# - NCT09876543: Study of Drug B for Alzheimer's
# - NCT04512345: Study of Drug X in Alzheimer's Patients
#
# Highlight key trial aspects:
#
# - Both trials are currently in Phase 2, which means they are evaluating the efficacy of the drugs in Alzheimer's patients.
# - The expected completion date for both trials is 2024-12-31.
#
# Explanation of technical terms:
#
# - (Phase 2): This is the stage of a clinical trial where the drug's safety and effectiveness are being studied in a larger group of people (several hundred) who have the disease or condition for which the drug is intended.
#
# Explanation of trials:
#
# - NCT09876543: Study of Drug B for Alzheimer's
# 	+ This trial is recruiting patients to evaluate the efficacy of Drug B in Alzheimer's patients.
# 	+ The primary outcome measure is the change in Alzheimer's Disease Assessment Scale-Cognitive Subscale (ADAS-Cog) score from baseline to week 24.
# 	+ The secondary outcome measures include changes in other cognitive and functional scales, as well as changes in biomarkers of Alzheimer's disease.
# - NCT04512345: Study of Drug X in Alzheimer's Patients
# 	+ This trial is also recruiting patients to evaluate the efficacy of Drug X in Alzheimer's patients.
# 	+ The primary outcome measure is the change in ADAS-Cog score from baseline to week 24.
# 	+ The secondary outcome measures include changes in other cognitive and functional scales, as well as changes in biomarkers of Alzheimer's disease.
#
# In conclusion, these two latest clinical trials for Alzheimer's using drug interventions are both in Phase 2 and aim to evaluate the efficacy of Drug B and Drug X in Alzheimer's patients. The primary outcome measure for both trials is the change in ADAS-Cog score from baseline to week 24, and the secondary outcome measures include changes in other cognitive and functional scales, as well as changes in biomarkers of Alzheimer's disease.
#
#     Detailed Information:
#
#         Trial ID: NCT09876543
#         • Title: Study of Drug B for Alzheimer's
#         • Condition: Alzheimer's Disease
#         • Phase: Phase 2 (Efficacy and side effect testing in larger groups (100-300))
#         • Status: Recruiting (Currently accepting participants)
#         • Interventions: Drug B, Placebo
#         • Timeline: 2023-07-01 to 2024-12-31
#
#         Trial ID: NCT04512345
#         • Title: Study of Drug X in Alzheimer's Patients
#         • Condition: Alzheimer's Disease
#         • Phase: Phase 2 (Efficacy and side effect testing in larger groups (100-300))
#         • Status: Recruiting (Currently accepting participants)
#         • Interventions: Drug X, Placebo
#         • Timeline: 2023-01-01 to 2024-12-31
#
#         Trial ID: NCT05678901
#         • Title: Trial of Compound Y for Early Alzheimer's
#         • Condition: Alzheimer's Disease
#         • Phase: Phase 3 (Large-scale testing for regulatory approval (1,000-3,000))
#         • Status: Completed (Finished data collection, results analysis ongoing)
#         • Interventions: Compound Y, Cognitive Therapy
#         • Timeline: 2022-06-15 to 2023-12-31
# ================================================================================
#
# ================================================================================
# Healthcare Worker:
#
# Regarding your request to show clinical trials for Parkinson's Disease that are in Phase 1/2 and are active, I have reviewed the available data and found the following:
#
# - **NCT03456789** (Pharmacokinetics of Drug Z in Parkinson's patients)
# 	+ Phase: 1
# 	+ Status: Active
# 	+ Key Aspects: This trial focuses on investigating the absorption, distribution, metabolism, and excretion (pharmacokinetics) of Drug Z in individuals with Parkinson's disease. Although it is in Phase 1, it does not meet the criteria of being in Phase 1/2.
#
# - **NCT22334455** (Gene therapy trial for Parkinson's disease)
# 	+ Phase: Not yet recruiting
# 	+ Status: Not active
# 	+ Key Aspects: This trial involves the use of gene therapy, a technique that introduces genetic material into cells to correct abnormal genes or to produce a beneficial protein. Although this trial is a gene therapy trial for Parkinson's disease, it is not yet recruiting and therefore not active.
#
# - **NCT55667788** (Digital therapy trial for managing Parkinson's motor symptoms)
# 	+ Phase: 3
# 	+ Status: Not active
# 	+ Key Aspects: This trial investigates the use of digital therapy, which involves the use of digital technology to improve health outcomes, for managing Parkinson's motor symptoms. However, it is in Phase 3 and not in Phase 1/2.
#
# In summary, based on the provided information, there are currently no clinical trials for Parkinson's Disease that are in Phase 1/2 and are active. The trials mentioned above either do not meet the phase requirement or are not yet active.
#
# Please let me know if you have any further questions or concerns.
#
# Best regards,
# [Your Name]
#
#     Detailed Information:
#
#         Trial ID: NCT22334455
#         • Title: Gene Therapy Trial for Parkinson's Disease
#         • Condition: Parkinson's Disease
#         • Phase: Phase 1/2 (Combined safety and preliminary efficacy testing)
#         • Status: Not yet recruiting (Approved but not yet started)
#         • Interventions: Gene Therapy Vector
#         • Timeline: 2024-01-01 to 2026-12-31
#
#         Trial ID: NCT03456789
#         • Title: Investigation of Drug Z for Parkinson's
#         • Condition: Parkinson's Disease
#         • Phase: Phase 1 (Initial safety testing in small groups (20-80 participants))
#         • Status: Active (Ongoing but not currently recruiting)
#         • Interventions: Drug Z
#         • Timeline: 2023-03-01 to 2024-06-30
#
#         Trial ID: NCT55667788
#         • Title: Digital Therapy for Parkinson's Symptom Management
#         • Condition: Parkinson's Disease
#         • Phase: Phase 3 (Large-scale testing for regulatory approval (1,000-3,000))
#         • Status: Recruiting (Currently accepting participants)
#         • Interventions: Digital Therapy App
#         • Timeline: 2023-12-01 to 2025-06-30
# ================================================================================
#
# ================================================================================
# 1. What trials are testing preventive vaccines?
#    - NCT44556677: A Phase 2 trial for a preventive vaccine in high-risk Alzheimer's patients.
#
# 2. Highlight key trial aspects:
#    - **Trial Identifier:** NCT44556677
#    - **Trial Phase:** Phase 2
#    - **Disease:** Alzheimer's
#    - **Patient Population:** High-risk patients
#    - **Intervention:** Preventive vaccine
#    - **Trial Status:** Terminated due to safety concerns
#
# 3. Explanation of technical terms:
#    - **Phase 2 trial:** Refers to the second of three phases required by the Food and Drug Administration (FDA) in clinical trials for a new drug or vaccine. In Phase 2, the drug or vaccine is given to a larger group of people (100-300) to see if it is effective and to further evaluate its safety.
#    - **High-risk patients:** Individuals who are more likely to develop a certain disease or condition due to genetic, environmental, or lifestyle factors.
#    - **Preventive vaccine:** A type of vaccine that is given to healthy individuals to prevent them from getting a specific disease.
#    - **Terminated:** The trial was stopped before completion due to safety concerns.
#
# 4. Key points to consider:
#    - The trial was focused on testing a preventive vaccine for Alzheimer's disease in high-risk patients.
#    - The trial was in Phase 2, meaning it was evaluating the vaccine's effectiveness and safety in a larger group of people.
#    - Unfortunately, the trial was terminated due to safety concerns, indicating that the vaccine may have caused adverse effects in some participants.
#
# 5. Implications for healthcare workers:
#    - It is important to be aware of the current status of clinical trials for preventive vaccines in Alzheimer's disease.
#    - The termination of this trial due to safety concerns highlights the need for ongoing monitoring and evaluation of new treatments.
#    - Healthcare workers should continue to follow developments in this area and consider the potential risks and benefits of future preventive vaccines for Alzheimer's disease.
#
#     Detailed Information:
#
#         Trial ID: NCT44556677
#         • Title: Preventive Vaccine for Alzheimer's
#         • Condition: Alzheimer's Disease
#         • Phase: Phase 2 (Efficacy and side effect testing in larger groups (100-300))
#         • Status: Terminated (Permanently stopped before completion)
#         • Interventions: Vaccine X-101
#         • Timeline: 2023-04-01 to 2023-12-31
#
#         Trial ID: NCT05678901
#         • Title: Trial of Compound Y for Early Alzheimer's
#         • Condition: Alzheimer's Disease
#         • Phase: Phase 3 (Large-scale testing for regulatory approval (1,000-3,000))
#         • Status: Completed (Finished data collection, results analysis ongoing)
#         • Interventions: Compound Y, Cognitive Therapy
#         • Timeline: 2022-06-15 to 2023-12-31
#
#         Trial ID: NCT33445566
#         • Title: Stem Cell Treatment for Multiple Sclerosis
#         • Condition: Multiple Sclerosis
#         • Phase: Phase 3 (Large-scale testing for regulatory approval (1,000-3,000))
#         • Status: Active (Ongoing but not currently recruiting)
#         • Interventions: Stem Cell Injection
#         • Timeline: 2023-10-01 to 2025-06-30
# ================================================================================
#
# 👋 Ending session...

# %%
# Out:
# 🚀 Clinical Trial Query System (Using Groq)
# ➤ Enter 'exit' to quit
#
#
# ❌ Error: BaseModel.__init__() takes 1 positional argument but 2 were given
