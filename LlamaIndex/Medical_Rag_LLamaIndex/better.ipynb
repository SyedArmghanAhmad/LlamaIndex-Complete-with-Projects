# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, Settings, StorageContext
from llama_index.core.postprocessor import SimilarityPostprocessor, KeywordNodePostprocessor
from llama_index.retrievers.bm25 import BM25Retriever
from llama_index.core.response_synthesizers import TreeSummarize
from llama_index.llms.groq import Groq
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core.query_engine import RetrieverQueryEngine
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Configure settings
Settings.llm = Groq(model="llama-3.1-8b-instant", api_key=os.getenv("GROQ_API_KEY"))
Settings.embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
Settings.chunk_size = 512  # Smaller chunks for faster processing
Settings.chunk_overlap = 50

# Load and index documents with persistent storage
persist_dir = "./storage"
if not os.path.exists(persist_dir):
    documents = SimpleDirectoryReader("medical_papers").load_data()
    index = VectorStoreIndex.from_documents(documents)
    index.storage_context.persist(persist_dir=persist_dir)
else:
    storage_context = StorageContext.from_defaults(persist_dir=persist_dir)
    index = VectorStoreIndex([], storage_context=storage_context)

# Create hybrid retriever
vector_retriever = index.as_retriever(similarity_top_k=10)  # Increased from 7
bm25_retriever = BM25Retriever.from_defaults(index=index, similarity_top_k=10)

class HybridRetriever:
    def __init__(self, vector_retriever, bm25_retriever):
        self.vector_retriever = vector_retriever
        self.bm25_retriever = bm25_retriever

    def retrieve(self, query):
        vector_nodes = self.vector_retriever.retrieve(query)
        bm25_nodes = self.bm25_retriever.retrieve(query)
        all_nodes = vector_nodes + bm25_nodes
        return sorted(all_nodes, key=lambda n: n.score, reverse=True)[:15]  # Top 15

# Create query engine
query_engine = RetrieverQueryEngine.from_args(
    retriever=HybridRetriever(vector_retriever, bm25_retriever),
    node_postprocessors=[
        SimilarityPostprocessor(similarity_cutoff=0.75),  # Increased from 0.7
        KeywordNodePostprocessor(
            required_keywords=["treatment", "diabetes", "hypertension", "AI"],  # More specific
            exclude_keywords=["animal", "vitro", "study", "unrelated"]  # Exclude noisy terms
        )
    ],
    response_mode="compact"  # Faster than tree_summarize
)

# Warm-up phase
def warmup():
    _ = query_engine.retriever.retrieve("warmup")
    _ = Settings.llm.complete("warmup")

warmup()

# Query interface
query_cache = {}  # Cache to store responses

while True:
    try:
        query = input("\nEnter your medical question (or 'exit' to quit): ").strip()
        if query.lower() == "exit":
            break

        # Validate query
        if not query or len(query.split()) < 2:
            print("Please enter a valid question with at least 2 words.")
            continue

        # Check cache
        if query in query_cache:
            print("\nAnswer (from cache):")
            print(query_cache[query])
            continue

        # Execute query
        response = query_engine.query(query)
        if not response.source_nodes:
            print("No relevant information found. Try rephrasing or asking about:")
            print("- Diabetes insipidus treatments")
            print("- PAH management strategies")
            print("- AI applications in radiology")
        else:
            print(f"\nAnswer: {response}\n")
            print("Sources:")
            unique_responses = set()
            for node in response.source_nodes:
                if node.score > 0.7 and node.text not in unique_responses:  # Only show high-confidence, unique sources
                    unique_responses.add(node.text)
                    print(f"- {node.text[:200]}... (Score: {node.score:.2f})")

            # Cache the response
            query_cache[query] = response

    except Exception as e:
        print(f"An error occurred: {e}. Please try again.")
# Out:
# Answer: AI can be used to design and optimize the development of nanoparticles for cancer immunotherapy by analyzing large datasets and identifying patterns that can inform the creation of more effective and targeted nanoparticles. This can include the use of machine learning algorithms to predict the behavior of nanoparticles in different environments and to identify the most promising candidates for further development. Additionally, AI can be used to simulate the interactions between nanoparticles and cancer cells, allowing researchers to test different designs and mechanisms without the need for physical experimentation.
#
# Sources:
# - Page 11 of 48
# Lu et al. Journal of Hematology & Oncology            (2024) 17:16
# These nanoparticles target macrophages, enhancing anti -
# gen processing and expediting T-cell-related responses in
# ca... (Score: 5.00)
# - Rainey et al. AI-Related Survey of UK Radiographers
# FIGURE 3 | Respondents’ perception of understanding of the term “arti ﬁcial intelligence” [(A), diagnostic radiography, (B) therapeutic radiography]... (Score: 4.79)
#
# Answer: Rewrite: In the context of radiography, advancements in AI and nanotechnology may intersect to enhance diagnostic capabilities, such as image analysis and tumor detection, rather than developing targeted treatments. This integration could lead to breakthroughs in areas such as personalized medicine, cancer treatment, and regenerative medicine, with a particular emphasis on improving the accuracy and effectiveness of radiographic imaging, including diagnostic and therapeutic applications.
#
# Sources:
# - This
# may indicate that, perhaps, initial reported “conﬁdence” was
# surrounding AI in general rather than AI in radiography
# and modern AI. Abuzaid et al. (
# 35) surveyed radiographers
# and radiologists in... (Score: 6.29)
# - Most codes were common across both
# professions ( Supplementary Figure 2 ). Four general themes
# emerged from thematic analysis: (i) clinical applications of AI,
# (ii) advantages of AI, (iii) disadvantag... (Score: 4.85)
# - Focus should be given on different needs of learners dependi ng on age, gender, and
# highest qualiﬁcation to ensure optimal integration.
# Keywords: artiﬁcial intelligence, AI, radiography, education, wo... (Score: 4.55)
# - Rainey et al. AI-Related Survey of UK Radiographers
# FIGURE 1 | Respondents’ understanding of the terminology of modern AI.
# FIGURE 2 | Development of skill in AI.
# Development of Skill in AI
# Most of bot... (Score: 4.48)
# - 44. Cambridge, MA: Academic Press (2011), 247–
# 96. doi: 10.1016/B978-0-12-385522-0.00005-6
# 65. Ehrlinger J, Dunning D. How chronic self-views inﬂuence (and
# potentially mislead) estimates of performanc... (Score: 4.48)
# - . use of computer algorithms to do mundane tasks e.g.,
# outlining organs at risk (OAR).”
# “The use of complex interconnecting self-designing
# algorithms to achieve a speciﬁc outcome. . . ”
# (iii) clinical... (Score: 4.25)
# - Rainey et al. AI-Related Survey of UK Radiographers
# would speed the collection of clinical data. In Germany, 83% o f
# 263 surveyed medical students felt that AI will never replace th e
# radiologist ( 11... (Score: 4.15)
# - Rainey et al. AI-Related Survey of UK Radiographers
# FIGURE 3 | Respondents’ perception of understanding of the term “arti ﬁcial intelligence” [(A), diagnostic radiography, (B) therapeutic radiography]... (Score: 3.76)
#
# Answer: While managing diabetes insipidus and pulmonary arterial hypertension may seem like unrelated conditions, there are some commonalities in their treatment approaches. In both conditions, monitoring and managing fluid balance is crucial. For diabetes insipidus, patients need to be closely monitored for excessive and inappropriately dilute urine output, and fluid replacement is optimized to prevent dehydration. Similarly, in pulmonary arterial hypertension, fluid balance is a critical factor, and patients may need to limit their fluid intake to prevent fluid overload and worsening of symptoms.
#
# Another overlapping strategy is the importance of regular monitoring and follow-up. In diabetes insipidus, patients require close postoperative follow-up and regular checks for electrolyte imbalances and water intoxication. Similarly, in pulmonary arterial hypertension, regular monitoring of symptoms, exercise capacity, and hemodynamics is essential to adjust treatment and prevent clinical worsening.
#
# Lastly, patient education and counseling play a vital role in both conditions. In diabetes insipidus, patients and their families need to be educated about the treatment regime and how to manage their condition. Similarly, in pulmonary arterial hypertension, patients need to be educated about their condition, treatment options, and lifestyle modifications to manage their symptoms and prevent clinical worsening.
#
# While the underlying pathophysiology of these conditions is different, there are some commonalities in their treatment approaches that highlight the importance of fluid balance, regular monitoring, and patient education.
#
# Sources:
# - 005
# Copeptin <2.5 pmol/L
# Table 2: General management strategies for a patient
# with diabetes insipidus
# Immediate postoperative period
# • Assessment of volume and hydration status; measurement
# of seru... (Score: 6.71)
# - 137 Zamanian RT, Hedlin H, Greuenwald P, et al. Features and outcomes of methamphetamine-associated
# pulmonary arterial hypertension.Am J Respir Crit Care Med2018; 197: 788– 800.
# 138 Salvador ML, Rodrí... (Score: 6.35)
# - O. Sitbon reports grants from Aerovate, AOP Orphan, Ferrer, Janssen and
# MSD, consultancy fees from Altavant/Enzyvant, AOP Orphan, Ferrer, Gossamer Bio, Janssen, Liquidia, MSD, Respira
# Therapeutics and... (Score: 5.89)
# - 44 Kylhammar D, Kjellström B, Hjalmarsson C, et al. A comprehensive risk stratification at early follow-up
# determines prognosis in pulmonary arterial hypertension.Eur Heart J2018; 39: 4175– 4181.
# 45 M... (Score: 5.84)
#
# Answer: While there isn't a specific mention of the latest breakthroughs in treating rare diseases in the provided context, it does highlight the challenges and management principles of certain conditions, such as central diabetes insipidus, particularly in vulnerable populations like the elderly and those with hypodipsia/adipsia.
#
# However, one potential area of interest is the discussion on the management of central diabetes insipidus in pregnancy. The papers mention that the doses needed for pregnant women are usually the same or slightly higher, and that DDAVP can be discontinued 4-6 weeks postpartum. This information could be seen as a breakthrough in understanding the treatment of central diabetes insipidus in a specific population.
#
# Additionally, the papers touch on the importance of careful electrolyte and fluid balance monitoring in patients with central diabetes insipidus, particularly in the elderly, who are at a higher risk of developing hyponatremia. This highlights the need for personalized and nuanced approaches to managing rare diseases.
#
# It's worth noting that the provided context primarily focuses on the management and treatment of central diabetes insipidus, rather than breakthroughs in treating rare diseases more broadly.
#
# Sources:
# - A smaller dose of 0.06–0.125 µg is usually
# preferred with further titration to the desired effects
# for patients who are unable to drink at will or are on IV
# fluids. Although hyponatremia can be a m... (Score: 3.95)
# - 91,92
# Compared to non-pregnant women, the doses needed
# are usually the same or slightly higher. Placental leucine
# aminopeptidase usually disappears in 4–6 postpartum
# weeks when DDAVP can be discon... (Score: 3.64)
# - Checkpoint inhibitors
# can cause immune-related adverse events (IRAEs), depending
# on the speciﬁc therapy.275 There is a theoretical concern that
# vaccination could stimulate an over-reactive immune resp... (Score: 3.33)
#
# Answer: Research has shown that AI can be a valuable tool in detecting abnormalities in medical imaging, particularly in tasks that require pattern recognition, such as identifying cancers. AI systems can learn to identify patterns in medical images and make predictions with a high degree of accuracy. However, the effectiveness of AI in detecting abnormalities can depend on various factors, including the quality of the training data, the complexity of the images, and the specific application being used.
#
# In some cases, AI can outperform traditional methods in detecting abnormalities, especially in tasks that are prone to human error or require a high degree of objectivity. For example, AI can be used to automate the detection of abnormalities in mammography images, which can help reduce the workload of radiologists and improve the accuracy of diagnoses.
#
# However, AI is not a replacement for human expertise, and it is often used in conjunction with traditional methods to improve the accuracy and efficiency of medical imaging analysis. The integration of AI into medical imaging workflows can also help to identify potential biases and errors in traditional methods, leading to improved patient outcomes.
#
# Ultimately, the comparison between AI and traditional methods in detecting abnormalities in medical imaging depends on the specific application and the quality of the technology being used. As AI technology continues to evolve, it is likely that we will see even more effective and efficient methods for detecting abnormalities in medical imaging.
#
# Sources:
# - Similarly medical
# students have reported either no AI training at all or insuﬃci ent
# training in AI with many believing it should be taught at
# undergraduate level and be part of the compulsory curricu... (Score: 5.77)
# - Most codes were common across both
# professions ( Supplementary Figure 2 ). Four general themes
# emerged from thematic analysis: (i) clinical applications of AI,
# (ii) advantages of AI, (iii) disadvantag... (Score: 5.37)
# - The Impact of AI on Radiographers
# Radiographers are registered healthcare professionals who work
# predominantly and directly with patients, families, carers,
# and service users but very closely with Rad... (Score: 5.23)
# - Focus should be given on different needs of learners dependi ng on age, gender, and
# highest qualiﬁcation to ensure optimal integration.
# Keywords: artiﬁcial intelligence, AI, radiography, education, wo... (Score: 4.82)
# - It is essential
# for the design, validation, and adoption of AI that radiograph ers
# are knowledgeable, competent, conﬁdent, and well-trained t o be
# able to fully materialise the beneﬁts of new technolo... (Score: 4.80)
# - Rainey et al. AI-Related Survey of UK Radiographers
# FIGURE 3 | Respondents’ perception of understanding of the term “arti ﬁcial intelligence” [(A), diagnostic radiography, (B) therapeutic radiography]... (Score: 4.75)
# - 91,92
# Compared to non-pregnant women, the doses needed
# are usually the same or slightly higher. Placental leucine
# aminopeptidase usually disappears in 4–6 postpartum
# weeks when DDAVP can be discon... (Score: 4.48)
#
# Answer: **Rewrite**: The challenges of implementing AI in radiology include a lack of trust and acceptance of AI systems among radiographers, inadequate training for radiographers to effectively utilize AI capabilities, inconsistent regulatory frameworks for AI-enabled healthcare products, and insufficient scrutiny of reported studies to establish a robust knowledge base. Additionally, there is a perceived lack of availability of AI training for radiographers, with a significant proportion of respondents disagreeing or strongly disagreeing with the statement that they have access to adequate training provisions for AI implementation.
#
# Sources:
# - Rainey et al. AI-Related Survey of UK Radiographers
# FIGURE 5 | Perception of AI training availability for radiographers.
# FIGURE 6 | Perception of ‘adequacy of radiographers’ AI training for c linical ... (Score: 6.19)
# - Similarly medical
# students have reported either no AI training at all or insuﬃci ent
# training in AI with many believing it should be taught at
# undergraduate level and be part of the compulsory curricu... (Score: 5.63)
# - Focus should be given on different needs of learners dependi ng on age, gender, and
# highest qualiﬁcation to ensure optimal integration.
# Keywords: artiﬁcial intelligence, AI, radiography, education, wo... (Score: 5.51)
# - This
# may indicate that, perhaps, initial reported “conﬁdence” was
# surrounding AI in general rather than AI in radiography
# and modern AI. Abuzaid et al. (
# 35) surveyed radiographers
# and radiologists in... (Score: 5.12)
# - Published literatu re agrees that AI is likely to have
# signiﬁcant impact on radiology practice. As radiographers are at the forefront of radiology
# service delivery, an awareness of the current level o... (Score: 5.05)
# - Rainey et al. AI-Related Survey of UK Radiographers
# would speed the collection of clinical data. In Germany, 83% o f
# 263 surveyed medical students felt that AI will never replace th e
# radiologist ( 11... (Score: 4.91)
# - Rainey et al. AI-Related Survey of UK Radiographers
# errors and job displacement. A further 69% felt that AI could
# lead to reductions in radiation dose whilst maintaining image
# quality. Overall, they c... (Score: 4.87)
# - Rainey et al. AI-Related Survey of UK Radiographers
# FIGURE 3 | Respondents’ perception of understanding of the term “arti ﬁcial intelligence” [(A), diagnostic radiography, (B) therapeutic radiography]... (Score: 4.62)
# - Meijering M. A bird’s-eye view of deep learning in bioimage analy sis.
# Comput Struct Biotechnol J. (2020) 18:2312–25. doi: 10.1016/j.csbj.2020.0
# 8.003
# 4. England JR, Cheng PM. Artiﬁcial intelligence f... (Score: 4.41)
# - While research related to radiologists’ roles, clinical prac tise,
# and education in relation to AI has ﬂourished, as discussed i n the
# abovementioned paragraphs, very little research has consider ed
# t... (Score: 4.33)
#
# Answer: In the context of disseminating knowledge to many clinical centres throughout the UK, convolutional neural networks (CNNs) are being explored for their potential in radiology, particularly for image recognition tasks. These networks can learn iteratively from large datasets, refining their performance until they meet the standards set by experienced radiologists.
#
# Sources:
# - Focus should be given on different needs of learners dependi ng on age, gender, and
# highest qualiﬁcation to ensure optimal integration.
# Keywords: artiﬁcial intelligence, AI, radiography, education, wo... (Score: 8.66)
# - . use of computer algorithms to do mundane tasks e.g.,
# outlining organs at risk (OAR).”
# “The use of complex interconnecting self-designing
# algorithms to achieve a speciﬁc outcome. . . ”
# (iii) clinical... (Score: 4.91)
# - Similarly medical
# students have reported either no AI training at all or insuﬃci ent
# training in AI with many believing it should be taught at
# undergraduate level and be part of the compulsory curricu... (Score: 3.46)
# - 44. Cambridge, MA: Academic Press (2011), 247–
# 96. doi: 10.1016/B978-0-12-385522-0.00005-6
# 65. Ehrlinger J, Dunning D. How chronic self-views inﬂuence (and
# potentially mislead) estimates of performanc... (Score: 3.37)
# - Rainey et al. AI-Related Survey of UK Radiographers
# FIGURE 3 | Respondents’ perception of understanding of the term “arti ﬁcial intelligence” [(A), diagnostic radiography, (B) therapeutic radiography]... (Score: 3.30)
# - treatment for cancer with and without rituximab.Acta Oncol.
# 2014;53(9):1212–1220.
# 281. Bouaziz JD, Yanaba K, Venturi GM, et al. Therapeutic B cell
# depletion impairs adaptive and autoreactive CD4+T cel... (Score: 2.77)
# - This tested both the
# technical aspects of the survey format (face validity) as well as the
# suitability of the questions (content validity). Minor form atting
# issues involving diﬃculty in navigating to... (Score: 2.76)
# - Rainey et al. AI-Related Survey of UK Radiographers
# would speed the collection of clinical data. In Germany, 83% o f
# 263 surveyed medical students felt that AI will never replace th e
# radiologist ( 11... (Score: 2.41)
